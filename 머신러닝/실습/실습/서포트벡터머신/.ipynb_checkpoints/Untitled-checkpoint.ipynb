# %%
import numpy as np

from sklearn import datasets
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC

iris=datasets.load_iris()
x=iris["data"][:,(2,3)]
y=(iris["target"]==2).astype(np.float64)

svmclf=Pipeline([
    ("scaler",StandardScaler()),
    ("linear",LinearSVC(C=1,loss="hinge"))
    
])
svmclf.fit(x,y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('linear', LinearSVC(C=1, loss='hinge'))])

# %%
svmclf.predict([[5.5,1.7]])
# Out:
# array([1.])

# %%
from sklearn.datasets import make_moons
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

x,y=make_moons(n_samples=100,noise=0.15)
polysvmclf=Pipeline([
    ('poly',PolynomialFeatures(degree=3)),
    ("scaler",StandardScaler()),
    ("svmclf",LinearSVC(C=10,loss='hinge'))
])
polysvmclf.fit(x,y)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=3)),
#                 ('scaler', StandardScaler()),
#                 ('svmclf', LinearSVC(C=10, loss='hinge'))])

# %%
import matplotlib.pyplot as plt
plt.plot(x[:,0][y==0],x[:,1][y==0],"bs")
plt.plot(x[:,0][y==1],x[:,1][y==1],"g^")
plt.show()

# %%
def plot_predictions(clf, axes):
    x0s = np.linspace(axes[0], axes[1], 100)
    x1s = np.linspace(axes[2], axes[3], 100)
    x0, x1 = np.meshgrid(x0s, x1s)
    X = np.c_[x0.ravel(), x1.ravel()]
    y_pred = clf.predict(X).reshape(x0.shape)
    y_decision = clf.decision_function(X).reshape(x0.shape)
    plt.contourf(x0, x1, y_pred, cmap=plt.cm.brg, alpha=0.2)
    plt.contourf(x0, x1, y_decision, cmap=plt.cm.brg, alpha=0.1)
def plot_dataset(X, y, axes):
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs")
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^")
    plt.axis(axes)
    plt.grid(True, which='both')
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"$x_2$", fontsize=20, rotation=0)
plot_predictions(polysvmclf, [-1.5, 2.5, -1, 1.5])
plot_dataset(x, y, [-1.5, 2.5, -1, 1.5])
plt.show()

# %%
from sklearn.svm import SVC

polykernel=Pipeline([
    ('scaler',StandardScaler()),
    ('svmclf',SVC(kernel="poly",degree=3,coef0=1,C=5))
    
])
polykernel.fit(x,y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svmclf', SVC(C=5, coef0=1, kernel='poly'))])

# %%
plot_predictions(polykernel, [-1.5, 2.5, -1, 1.5])
plot_dataset(x, y, [-1.5, 2.5, -1, 1.5])
plt.show()

# %%
rbfkernel=Pipeline([
    ('scaler',StandardScaler()),
    ('svmclf',SVC(kernel='rbf',gamma=5,C=0.001))
])
rbfkernel.fit(x,y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svmclf', SVC(C=0.001, gamma=5))])

# %%
plot_predictions(rbfkernel, [-1.5, 2.5, -1, 1.5])
plot_dataset(x, y, [-1.5, 2.5, -1, 1.5])
plt.show()

# %%
from sklearn.svm import LinearSVR

svmreg=LinearSVR(epsilon=1.5)
svmreg.fit(x,y)
# Out:
# LinearSVR(epsilon=1.5)

# %%
from sklearn.svm import SVR

svmpoly=SVR(kernel="poly",degree=2 ,C=100,epsilon=0.1)
svmpoly.fit(x,y)
# Out:
# SVR(C=100, degree=2, kernel='poly')
